# %% [markdown]
# <a href="https://colab.research.google.com/github/Adithya759/Adithya/blob/main/Full_ETL_Task.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

df= pd.read_csv('https://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/all_month.csv')
df.head()
# Out:
#                        time   latitude   longitude    depth   mag magType  \
# 0  2025-07-21T06:12:57.570Z  36.079167 -117.619000   1.5900  1.07      ml
# 1  2025-07-21T06:08:16.330Z  35.948000 -117.666333   3.4200  0.26      ml
# 2  2025-07-21T05:44:40.819Z  64.645900 -149.397100  19.7000  2.20      ml
# 3  2025-07-21T05:43:42.750Z  18.258333  -66.338667  21.5000  1.95      md
# 4  2025-07-21T05:28:30.153Z  32.451000 -102.083000   4.9957  1.10      ml
#
#     nst    gap     dmin   rms  ...                   updated  \
# 0  25.0   75.0  0.10740  0.15  ...  2025-07-21T06:16:26.499Z
# 1  13.0   67.0  0.01295  0.08  ...  2025-07-21T06:11:37.459Z
# 2   NaN    NaN      NaN  0.77  ...  2025-07-21T05:46:56.248Z
# 3   9.0  123.0  0.06434  0.13  ...  2025-07-21T06:09:57.640Z
# 4  13.0  110.0  0.00000  0.50  ...  2025-07-21T06:00:14.519Z
#
#                                  place        type horizontalError depthError  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10840 entries, 0 to 10839
# Data columns (total 22 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   time             10840 non-null  object
#  1   latitude         10840 non-null  float64
#  2   longitude        10840 non-null  float64
#  3   depth            10840 non-null  float64
#  4   mag              10839 non-null  float64
#  5   magType          10839 non-null  object
#  6   nst              9045 non-null   float64
#  7   gap              9044 non-null   float64
#  8   dmin             8956 non-null   float64
#  9   rms              10839 non-null  float64
#  10  net              10840 non-null  object
#  11  id               10840 non-null  object
#  12  updated          10840 non-null  object
#  13  place            10840 non-null  object
#  14  type             10840 non-null  object
#  15  horizontalError  8415 non-null   float64
# ...

# %%
df.shape
# Out:
# (10840, 22)

# %%
num_records=len(df)
print(f"The number of records in the DataFrame id:{num_records}")
# Out:
# The number of records in the DataFrame id:10840

# %%
np.unique(df['place'])
# Out:
# array(['0 km  of The Geysers, CA', '0 km E of Carnelian Bay, California',
#        '0 km E of Indios, Puerto Rico', ..., 'west of Macquarie Island',
#        'western Indian-Antarctic Ridge', 'western Xizang'], dtype=object)

# %%
np.unique(df['locationSource'])
# Out:
# array(['ak', 'av', 'ci', 'hv', 'mb', 'nc', 'nm', 'nn', 'ok', 'pr', 'se',
#        'tx', 'us', 'uu', 'uw'], dtype=object)

# %%
df.head(5)
# Out:
#                        time   latitude   longitude    depth   mag magType  \
# 0  2025-07-21T06:12:57.570Z  36.079167 -117.619000   1.5900  1.07      ml
# 1  2025-07-21T06:08:16.330Z  35.948000 -117.666333   3.4200  0.26      ml
# 2  2025-07-21T05:44:40.819Z  64.645900 -149.397100  19.7000  2.20      ml
# 3  2025-07-21T05:43:42.750Z  18.258333  -66.338667  21.5000  1.95      md
# 4  2025-07-21T05:28:30.153Z  32.451000 -102.083000   4.9957  1.10      ml
#
#     nst    gap     dmin   rms  ...                   updated  \
# 0  25.0   75.0  0.10740  0.15  ...  2025-07-21T06:16:26.499Z
# 1  13.0   67.0  0.01295  0.08  ...  2025-07-21T06:11:37.459Z
# 2   NaN    NaN      NaN  0.77  ...  2025-07-21T05:46:56.248Z
# 3   9.0  123.0  0.06434  0.13  ...  2025-07-21T06:09:57.640Z
# 4  13.0  110.0  0.00000  0.50  ...  2025-07-21T06:00:14.519Z
#
#                                  place        type horizontalError depthError  \
# ...

# %%
 df.isna().sum()
# Out:
# time                  0
# latitude              0
# longitude             0
# depth                 0
# mag                   1
# magType               1
# nst                1795
# gap                1796
# dmin               1884
# rms                   1
# net                   0
# id                    0
# updated               0
# place                 0
# type                  0
# horizontalError    2425
# depthError            4
# magError           1895
# magNst             1799
# status                0
# locationSource        0
# magSource             0
# dtype: int64

# %%
 df.dropna(subset=['latitude','longitude', 'mag'],inplace=True)
 df.isna().sum()
# Out:
# time                  0
# latitude              0
# longitude             0
# depth                 0
# mag                   0
# magType               0
# nst                1795
# gap                1796
# dmin               1884
# rms                   1
# net                   0
# id                    0
# updated               0
# place                 0
# type                  0
# horizontalError    2424
# depthError            4
# magError           1894
# magNst             1798
# status                0
# locationSource        0
# magSource             0
# dtype: int64

# %%
df= df[df['mag']>=4.0]
df.head()
# Out:
#                         time  latitude  longitude    depth  mag magType   nst  \
# 12  2025-07-21T04:50:28.712Z    0.0526   123.1965  161.784  4.8      mb  70.0
# 18  2025-07-21T03:57:57.122Z   52.5882   160.4530   10.000  4.2      mb  22.0
# 26  2025-07-21T03:13:34.101Z   52.2416   160.3604   10.000  4.3      mb  32.0
# 29  2025-07-21T02:59:43.849Z  -23.8341   -68.3654  121.348  4.3      mb  28.0
# 30  2025-07-21T02:56:54.579Z   52.6526   160.4971   10.000  4.2      mb  28.0
#
#       gap   dmin   rms  ...                   updated  \
# 12   54.0  2.147  1.01  ...  2025-07-21T05:13:37.040Z
# 18  195.0  1.178  0.79  ...  2025-07-21T05:24:36.040Z
# 26  152.0  1.304  0.60  ...  2025-07-21T04:42:36.040Z
# 29  103.0  0.895  0.94  ...  2025-07-21T05:28:43.933Z
# 30  120.0  1.180  1.16  ...  2025-07-21T03:55:54.040Z
#
#                                              place        type  \
# 12               55 km SSE of Gorontalo, Indonesia  earthquake
# ...

# %%
day_of_week=df['day_of_week']=df['time'].dt.day_name()
df
# Out:
#                                   time  latitude  longitude    depth  mag  \
# 12    2025-07-21 04:50:28.712000+00:00    0.0526   123.1965  161.784  4.8
# 18    2025-07-21 03:57:57.122000+00:00   52.5882   160.4530   10.000  4.2
# 26    2025-07-21 03:13:34.101000+00:00   52.2416   160.3604   10.000  4.3
# 29    2025-07-21 02:59:43.849000+00:00  -23.8341   -68.3654  121.348  4.3
# 30    2025-07-21 02:56:54.579000+00:00   52.6526   160.4971   10.000  4.2
# ...                                ...       ...        ...      ...  ...
# 10825 2025-06-21 07:32:52.177000+00:00   64.5456   -39.9838   10.000  4.2
# 10826 2025-06-21 07:28:00.268000+00:00   64.5288   -39.8376   10.000  4.5
# 10829 2025-06-21 07:23:59.651000+00:00  -23.8402  -179.9618  525.024  4.3
# 10830 2025-06-21 07:23:50.833000+00:00  -23.9369  -179.8111  529.302  4.1
# 10839 2025-06-21 06:41:56.395000+00:00  -32.8303   179.7659  226.877  4.4
#
#       magType    nst    gap    dmin   rms  ...  \
# ...

# %%
def severity_level(mag):
  if mag < 4.0:
    return 'Low'
  elif 4.0 <= mag <= 6.0:
    return 'Moderate'
  else:
    return 'High'
